# %% [markdown]
# <a href="https://colab.research.google.com/github/Amany74/Algorithms/blob/main/Amany_Analysis_Barca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h1 style="color:red;font-size:3.3em;" >Barcelona </h1>
#
# Barcelona, the cosmopolitan *capital of Spain’s Catalonia region,*  and the largest city of the autonomous community of Catalonia, as well as the second most populous municipality of Spain. This notebook will explore data about Population,Births, Deaths and Accidents .

# %% [markdown]
# <h1> What is presented </h1>
#
# - Population by year
# - Age of the population by neighbourhood, year by year and by genre of the city of Barcelona
#
# - 25 Most common baby names in Barcelona, disaggregated by sex. Years 1996-2016
#
# -  50 Most common names of the inhabitants of Barcelona, disaggregated by decade of birth and sex

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns 
import plotly.express as px
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)  
import plotly.io as pio
pio.renderers.default = "colab"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Importing our data

# %%
p_y = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/pop growth 1950-2035.csv',header=0)
c_g = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/cities growth.csv',header=0)
population = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/population.csv',header=0)
births = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/births.csv',header=0)
deaths = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/deaths.csv',header=0)
accidents = pd.read_csv('/content/drive/MyDrive/Analysis/Barca Analysis/accidents_2017.csv',header=0)

# %%
# what is in population data ?
population.head()
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124

# %%
population.Year.unique()
# Out:
# array([2017, 2016, 2015, 2014, 2013])

# %% [markdown]
# - We got all population data from 2013 to 2017
#
# - Also i got the data from else where about population of cities far more to 2035

# %% [markdown]
# # What is the distiribution of our population?

# %%
p_y.columns
# Out:
# Index(['Year', 'Population', 'GrowthRate', 'Growth'], dtype='object')

# %%
years = p_y.Year
growth = p_y.Growth
pop = p_y.Population

# %%
fig = px.line(p_y, x=years, y=growth,title=' What is the Population Growth rates?')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(p_y, x=years, y=pop,title='Does the population increasing?')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## We find that the population from 2000 to 2020 is quite constant , But it's interesting why population predictions decreases in the future

# %% [markdown]
# ## What about Cities ?

# %% [markdown]
# Does the population growth increased with the country population ?
#
# Some cities groeth became negative !

# %%
df = c_g

fig = px.scatter(df, x=df.index, y="popGrowth",
	         size="pop2022", color="cityName",
                 hover_name="cityName", log_x=True, size_max=150)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pop = population.groupby(['Year' , 'Gender'])
pop.last()
# Out:
#              District.Code District.Name  Neighborhood.Code  \
# Year Gender
# 2013 Female             10    Sant Martí                 73
#      Male               10    Sant Martí                 73
# 2014 Female             10    Sant Martí                 73
#      Male               10    Sant Martí                 73
# 2015 Female             10    Sant Martí                 73
#      Male               10    Sant Martí                 73
# 2016 Female             10    Sant Martí                 73
#      Male               10    Sant Martí                 73
# 2017 Female             10    Sant Martí                 73
#      Male               10    Sant Martí                 73
#
#                Neighborhood.Name   Age  Number
# Year Gender
# 2013 Female  la Verneda i la Pau  >=95      47
#      Male    la Verneda i la Pau  >=95      14
# 2014 Female  la Verneda i la Pau  >=95      49
#      Male    la Verneda i la Pau  >=95      14
# ...

# %%
# Males and females along years
#2013 
female_2013 = pop.get_group((2013,'Female'))['Gender'].value_counts()[0]
male_2013 = pop.get_group((2013,'Male'))['Gender'].value_counts()[0]

#2014
female_2014 = pop.get_group((2014,'Female'))['Gender'].value_counts()[0]
male_2014 = pop.get_group((2014,'Male'))['Gender'].value_counts()[0]

#2015
female_2015 = pop.get_group((2015,'Female'))['Gender'].value_counts()[0]
male_2015 = pop.get_group((2015,'Male'))['Gender'].value_counts()[0]

#2016
female_2016 = pop.get_group((2016,'Female'))['Gender'].value_counts()[0]
male_2016 = pop.get_group((2016,'Male'))['Gender'].value_counts()[0]

#2017
female_2017 = pop.get_group((2017,'Female'))['Gender'].value_counts()[0]
male_2017 = pop.get_group((2017,'Male'))['Gender'].value_counts()[0]

#years
years = [2013,2014,2015,2016,2017]

# array of females 
females = [int(female_2013) , int(female_2014) , int(female_2015) , int(female_2016) , int(female_2017)]

#males along years
males = [int(male_2013) , int(male_2014) ,int(male_2015) ,int(male_2016) ,int(male_2017)]

# %%
# Districts
population['District.Name'].unique()
# Out:
# array(['Ciutat Vella', 'Eixample', 'Sants-Montjuïc', 'Les Corts',
#        'Sarrià-Sant Gervasi', 'Gràcia', 'Horta-Guinardó', 'Nou Barris',
#        'Sant Andreu', 'Sant Martí'], dtype=object)

# %% [markdown]
# # Year and District

# %%
pop = population.groupby(['Year' , 'District.Name'])
pop.first()
# Out:
#                           District.Code  Neighborhood.Code  \
# Year District.Name
# 2013 Ciutat Vella                     1                  1
#      Eixample                         2                  5
#      Gràcia                           6                 28
#      Horta-Guinardó                   7                 33
#      Les Corts                        4                 19
#      Nou Barris                       8                 44
#      Sant Andreu                      9                 57
#      Sant Martí                      10                 64
#      Sants-Montjuïc                   3                 11
#      Sarrià-Sant Gervasi              5                 22
# 2014 Ciutat Vella                     1                  1
#      Eixample                         2                  5
#      Gràcia                           6                 28
#      Horta-Guinardó                   7                 33
#      Les Corts                        4                 19
# ...

# %%
# ['Ciutat Vella', 'Eixample', 'Sants-Montjuïc', 'Les Corts',
#        'Sarrià-Sant Gervasi', 'Gràcia', 'Horta-Guinardó', 'Nou Barris',
#        'Sant Andreu', 'Sant Martí']

#I will mab district number in 2013 to district number in 2017

ciutat = int(pop.get_group((2013,'Ciutat Vella'))['Gender'].value_counts()[0]) 
eixample = int(pop.get_group((2013,'Eixample'))['Gender'].value_counts()[0]) 
sants = int(pop.get_group((2013,'Sants-Montjuïc'))['Gender'].value_counts()[0]) 
corts = int(pop.get_group((2013,'Les Corts'))['Gender'].value_counts()[0]) 
sarria =  int(pop.get_group((2013,'Sarrià-Sant Gervasi'))['Gender'].value_counts()[0]) 
horte = int(pop.get_group((2013,'Horta-Guinardó'))['Gender'].value_counts()[0]) 
barris = int(pop.get_group((2013,'Nou Barris'))['Gender'].value_counts()[0]) 
andreu = int(pop.get_group((2013,'Sant Andreu'))['Gender'].value_counts()[0])
marti = int(pop.get_group((2013,'Sant Martí'))['Gender'].value_counts()[0])
districts_2013= [ciutat , eixample,sants , corts , sarria , horte , barris , andreu , marti ]
districts_2013
# Out:
# [384, 576, 768, 288, 576, 1056, 1248, 672, 960]

# %%
# 2017 
districts = ['ciutat' , 'eixample','sants' , 'corts' , 'sarria' , 'horte' , 'barris' , 'andreu' , 'marti']
ciutat = int(pop.get_group((2017,'Ciutat Vella'))['Gender'].value_counts()[0]) 
eixample = int(pop.get_group((2017,'Eixample'))['Gender'].value_counts()[0]) 
sants = int(pop.get_group((2017,'Sants-Montjuïc'))['Gender'].value_counts()[0]) 
corts = int(pop.get_group((2017,'Les Corts'))['Gender'].value_counts()[0]) 
sarria =  int(pop.get_group((2017,'Sarrià-Sant Gervasi'))['Gender'].value_counts()[0]) 
horte = int(pop.get_group((2017,'Horta-Guinardó'))['Gender'].value_counts()[0]) 
barris = int(pop.get_group((2017,'Nou Barris'))['Gender'].value_counts()[0]) 
andreu = int(pop.get_group((2017,'Sant Andreu'))['Gender'].value_counts()[0])
marti = int(pop.get_group((2017,'Sant Martí'))['Gender'].value_counts()[0])
districts_2017= [ciutat , eixample,sants , corts , sarria , horte , barris , andreu , marti ]
districts_2017
# Out:
# [384, 576, 768, 288, 576, 1056, 1248, 672, 960]

# %%
fig = px.bar(districts, x=districts, y=districts_2013,
             labels={'ciutat' , 'eixample','sants' , 'corts' , 'sarria' , 'horte' , 'barris' , 'andreu' , 'marti'},color = districts,text_auto='.2s',title='Districts in 2013 counted by Gener' )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
age_brackets = population.groupby('Age')
age_brackets.last()
# Out:
#        Year  District.Code District.Name  Neighborhood.Code  \
# Age
# 0-4    2013             10    Sant Martí                 73
# 10-14  2013             10    Sant Martí                 73
# 15-19  2013             10    Sant Martí                 73
# 20-24  2013             10    Sant Martí                 73
# 25-29  2013             10    Sant Martí                 73
# 30-34  2013             10    Sant Martí                 73
# 35-39  2013             10    Sant Martí                 73
# 40-44  2013             10    Sant Martí                 73
# 45-49  2013             10    Sant Martí                 73
# 5-9    2013             10    Sant Martí                 73
# 50-54  2013             10    Sant Martí                 73
# 55-59  2013             10    Sant Martí                 73
# 60-64  2013             10    Sant Martí                 73
# 65-69  2013             10    Sant Martí                 73
# ...

# %% [markdown]
# # What happens to ages and what is the dominant age along years ?

# %%
population = population[population['Year'] == 2017]
fig = px.histogram(population, x="District.Name", color="Gender" , nbins=20,text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
